# %%
import altair as alt
import pandas as pd

# %%
auction_data = pd.read_csv("datasets/auction.csv")

# %%
auction_data.head()
# Out:
#     auctionid    bid   bidtime                     bidder  bidderrate  \
# 0  1638893549  175.0  2.230949               schadenfreud         0.0
# 1  1638893549  100.0  2.600116                      chuik         0.0
# 2  1638893549  120.0  2.600810                 kiwisstuff         2.0
# 3  1638893549  150.0  2.601076                 kiwisstuff         2.0
# 4  1638893549  177.5  2.909826  eli.flint@flightsafety.co         4.0
#
#    openbid  price                item   auction_type
# 0     99.0  177.5  Cartier wristwatch  3 day auction
# 1     99.0  177.5  Cartier wristwatch  3 day auction
# 2     99.0  177.5  Cartier wristwatch  3 day auction
# 3     99.0  177.5  Cartier wristwatch  3 day auction
# 4     99.0  177.5  Cartier wristwatch  3 day auction

# %%
auction_data.shape
# Out:
# (10681, 9)

# %%
alt.Chart(auction_data).mark_bar().encode(
    x='price',
    y='count():Q'
).properties(width=600)
# Out:
# ---------------------------------------------------------------------------
# MaxRowsError                              Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\altair\vegalite\v5\api.py:2520, in Chart.to_dict(self, *args, **kwargs)
#    2518     copy.data = core.InlineData(values=[{}])
#    2519     return super(Chart, copy).to_dict(*args, **kwargs)
# -> 2520 return super().to_dict(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\altair\vegalite\v5\api.py:838, in TopLevelMixin.to_dict(self, *args, **kwargs)
#     836 copy = self.copy(deep=False)  # type: ignore[attr-defined]
#     837 original_data = getattr(copy, "data", Undefined)
# --> 838 copy.data = _prepare_data(original_data, context)
#     840 if original_data is not Undefined:
#     841     context["data"] = original_data
#
# File ~\anaconda3\Lib\site-packages\altair\vegalite\v5\api.py:100, in _prepare_data(data, context)
# ...

# %%
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %%
alt.Chart(auction_data).mark_bar().encode(
    x='price',
    y='count():Q'
).properties(width=600)
# Out:
# C:\Users\enjol\anaconda3\Lib\site-packages\altair\utils\core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# C:\Users\enjol\anaconda3\Lib\site-packages\altair\utils\core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# C:\Users\enjol\anaconda3\Lib\site-packages\altair\utils\core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %%
alt.data_transformers.enable('default')
# Out:
# DataTransformerRegistry.enable('default')

# %%
alt.Chart(auction_data).mark_bar().encode(
    x='price',
    y='count():Q'
).properties(width=600)
# Out:
# ---------------------------------------------------------------------------
# MaxRowsError                              Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\altair\vegalite\v5\api.py:2520, in Chart.to_dict(self, *args, **kwargs)
#    2518     copy.data = core.InlineData(values=[{}])
#    2519     return super(Chart, copy).to_dict(*args, **kwargs)
# -> 2520 return super().to_dict(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\altair\vegalite\v5\api.py:838, in TopLevelMixin.to_dict(self, *args, **kwargs)
#     836 copy = self.copy(deep=False)  # type: ignore[attr-defined]
#     837 original_data = getattr(copy, "data", Undefined)
# --> 838 copy.data = _prepare_data(original_data, context)
#     840 if original_data is not Undefined:
#     841     context["data"] = original_data
#
# File ~\anaconda3\Lib\site-packages\altair\vegalite\v5\api.py:100, in _prepare_data(data, context)
# ...
